# %%
# Import the libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, SimpleRNN, GRU, LSTM, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

# %%
# Make the synthetic data
series = np.sin((0.1*np.arange(10000))**2)

# %%
# Plot the series (first 400 points)
plt.figure(figsize=(15,5))
plt.plot(series[1:400])
plt.show();

# %%
# Build the dataset
T = 200
D = 1
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T] # Get the set of T values
    X.append(x) # append those values into the dataset X
    y = series[t+T] # get the next value as the target
    Y.append(y) # add the target value to Y

# %%
# Make the arrays the correct shape (N x T x D)
X_arr = np.array(X).reshape(-1, T) # Now the data should be N x T
y_arr = np.array(Y)
N = len(X_arr)
print('X_arr shape:', X_arr.shape)
print('y_arr shape:', y_arr.shape)
# Out:
# X_arr shape: (9800, 200)
# y_arr shape: (9800,)

# %%
# Split into train and test sets
# Don't use train_test_split
# Model needs to make predictions, to train set is the first half, and test set is the second half
# Can use points in between the train set for the test set
X_train = X_arr[:-N//2]
y_train = y_arr[:-N//2]
X_test = X_arr[-N//2:]
y_test = y_arr[-N//2:]

# %% [markdown]
# ### Try an autoregressive linear model

# %%
# Define the layers of the model
i = Input(shape=(T,))
x = Dense(1)(i)

# Build the model
model = Model(i, x)

# Define how the model should be trained
model.compile(optimizer=Adam(lr=0.001),
              loss='mse')

# Train the mdoel
result = model.fit(x=X_train, y=y_train, # train on the first half of the dataset (don't use train_test_split)
                   epochs=25,
                   validation_data=(X_test, y_test)) # test on the second half of the dataset
# Out:
# Train on 4900 samples, validate on 4900 samples
# Epoch 1/25
# 4900/4900 [==============================] - 1s 221us/sample - loss: 1.2109 - val_loss: 0.8764
# Epoch 2/25
# 4900/4900 [==============================] - 0s 93us/sample - loss: 0.7460 - val_loss: 0.6228
# Epoch 3/25
# 4900/4900 [==============================] - 0s 92us/sample - loss: 0.5782 - val_loss: 0.5369
# Epoch 4/25
# 4900/4900 [==============================] - 1s 104us/sample - loss: 0.5260 - val_loss: 0.5127
# Epoch 5/25
# 4900/4900 [==============================] - 0s 97us/sample - loss: 0.5111 - val_loss: 0.5065
# Epoch 6/25
# 4900/4900 [==============================] - 0s 98us/sample - loss: 0.5070 - val_loss: 0.5054
# Epoch 7/25
# 4900/4900 [==============================] - 0s 95us/sample - loss: 0.5062 - val_loss: 0.5055
# Epoch 8/25
# 4900/4900 [==============================] - 0s 94us/sample - loss: 0.5072 - val_loss: 0.5052
# Epoch 9/25
# 4900/4900 [==============================] - 0s 95us/sample - loss: 0.5069 - val_loss: 0.5045
# Epoch 10/25
# 4900/4900 [==============================] - 1s 102us/sample - loss: 0.5071 - val_loss: 0.5051
# Epoch 11/25
# 4900/4900 [==============================] - 1s 118us/sample - loss: 0.5073 - val_loss: 0.5050
# Epoch 12/25
# 4900/4900 [==============================] - 0s 100us/sample - loss: 0.5071 - val_loss: 0.5048
# Epoch 13/25
# 4900/4900 [==============================] - 1s 104us/sample - loss: 0.5073 - val_loss: 0.5044
# Epoch 14/25
# 4900/4900 [==============================] - 0s 101us/sample - loss: 0.5076 - val_loss: 0.5038
# Epoch 15/25
# 4900/4900 [==============================] - 1s 132us/sample - loss: 0.5066 - val_loss: 0.5056
# Epoch 16/25
# 4900/4900 [==============================] - 1s 120us/sample - loss: 0.5074 - val_loss: 0.5041
# Epoch 17/25
# 4900/4900 [==============================] - 1s 116us/sample - loss: 0.5074 - val_loss: 0.5042
# Epoch 18/25
# 4900/4900 [==============================] - 1s 120us/sample - loss: 0.5076 - val_loss: 0.5049
# Epoch 19/25
# 4900/4900 [==============================] - 1s 123us/sample - loss: 0.5076 - val_loss: 0.5047
# Epoch 20/25
# 4900/4900 [==============================] - 0s 90us/sample - loss: 0.5070 - val_loss: 0.5046
# Epoch 21/25
# 4900/4900 [==============================] - 0s 97us/sample - loss: 0.5077 - val_loss: 0.5045
# Epoch 22/25
# 4900/4900 [==============================] - 0s 89us/sample - loss: 0.5074 - val_loss: 0.5038
# Epoch 23/25
# 4900/4900 [==============================] - 0s 91us/sample - loss: 0.5074 - val_loss: 0.5048
# Epoch 24/25
# 4900/4900 [==============================] - 0s 94us/sample - loss: 0.5075 - val_loss: 0.5045
# Epoch 25/25
# 4900/4900 [==============================] - 0s 94us/sample - loss: 0.5079 - val_loss: 0.5046

# %%
# Plot the cost function at each itteration
# Note: model.fit() returns an object that contains the history of the training process
plt.plot(result.history['loss'], label='train_mse');
plt.plot(result.history['val_loss'], label='val_mse');
plt.legend();

# %% [markdown]
# Try to make a forecast

# %%
# create the lists
validation_target = y_test[-T:]
data_for_next_prediction = X_test[-T]
validation_predictions = []

# start index at 0
i = 0

# make predictions
while len(validation_predictions) < len(validation_target):
    # Make prediction using available data (including predicted data)
    prediction = model.predict(data_for_next_prediction.reshape(1,-1))[0,0] # need to reshape for to get it into the right format
    
    # Use the last 10 data points for the next prediction
    data_for_next_prediction = np.roll(data_for_next_prediction, -1)
    data_for_next_prediction[-1] = prediction
    
    # Add prediction to set of predictions
    validation_predictions.append(prediction)

# %%
# plot predicted vs actual test data
plt.figure(figsize=(15,5))
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend();

# %% [markdown]
# That's terrible

# %% [markdown]
# ### Try a SimpleRNN

# %%
# Reshape the data
X_arr = X_arr.reshape(-1, T, 1)

# Split into train and test sets
X_train = X_arr[:-N//2]
X_test = X_arr[-N//2:]

# %%
# Define the layers of the model
i = Input(shape=(T, D))
x = SimpleRNN(10)(i) # Defailt activation is activation='tanh'
x = Dense(1)(x)

# Build the model
model = Model(i, x)

# Define how the model should be trained
model.compile(optimizer=Adam(lr=0.002),
              loss='mse')

# Train the mdoel
result = model.fit(x=X_train, y=y_train, # train on the first half of the dataset (don't use train_test_split)
                   epochs=25,
                   validation_data=(X_test, y_test)) # test on the second half of the dataset
# Out:
# Train on 4900 samples, validate on 4900 samples
# Epoch 1/25
# 4900/4900 [==============================] - 14s 3ms/sample - loss: 0.5147 - val_loss: 0.4456
# Epoch 2/25
# 4900/4900 [==============================] - 13s 3ms/sample - loss: 0.4141 - val_loss: 0.3609
# Epoch 3/25
# 4900/4900 [==============================] - 13s 3ms/sample - loss: 0.2829 - val_loss: 0.1945
# Epoch 4/25
# 4900/4900 [==============================] - 14s 3ms/sample - loss: 0.1365 - val_loss: 0.0962
# Epoch 5/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0785 - val_loss: 0.0712
# Epoch 6/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0592 - val_loss: 0.0559
# Epoch 7/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0491 - val_loss: 0.0484
# Epoch 8/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0439 - val_loss: 0.0482
# Epoch 9/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0392 - val_loss: 0.0411
# Epoch 10/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0355 - val_loss: 0.0367
# Epoch 11/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0318 - val_loss: 0.0388
# Epoch 12/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0288 - val_loss: 0.0293
# Epoch 13/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0246 - val_loss: 0.0264
# Epoch 14/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0223 - val_loss: 0.0233
# Epoch 15/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0202 - val_loss: 0.0213
# Epoch 16/25
# 4900/4900 [==============================] - 16s 3ms/sample - loss: 0.0186 - val_loss: 0.0196
# Epoch 17/25
# 4900/4900 [==============================] - 15s 3ms/sample - loss: 0.0170 - val_loss: 0.0198
# Epoch 18/25
# 4900/4900 [==============================] - 12s 3ms/sample - loss: 0.0159 - val_loss: 0.0169
# Epoch 19/25
# 4900/4900 [==============================] - 12s 3ms/sample - loss: 0.0149 - val_loss: 0.0179
# Epoch 20/25
# 4900/4900 [==============================] - 12s 3ms/sample - loss: 0.0138 - val_loss: 0.0175
# Epoch 21/25
# 4900/4900 [==============================] - 12s 3ms/sample - loss: 0.0131 - val_loss: 0.0153
# Epoch 22/25
# 4900/4900 [==============================] - 14s 3ms/sample - loss: 0.0119 - val_loss: 0.0133
# Epoch 23/25
# 4900/4900 [==============================] - 15s 3ms/sample - loss: 0.0112 - val_loss: 0.0127
# Epoch 24/25
# 4900/4900 [==============================] - 13s 3ms/sample - loss: 0.0102 - val_loss: 0.0116
# Epoch 25/25
# 4900/4900 [==============================] - 13s 3ms/sample - loss: 0.0095 - val_loss: 0.0119

# %%
# Plot the cost function at each itteration
# Note: model.fit() returns an object that contains the history of the training process
plt.plot(result.history['loss'], label='train_mse');
plt.plot(result.history['val_loss'], label='val_mse');
plt.legend();

# %% [markdown]
# Try to make a forecast

# %%
# create the lists
validation_target = y_test[-T:]
data_for_next_prediction = X_test[-T]
validation_predictions = []

# start index at 0
i = 0

# make predictions
while len(validation_predictions) < len(validation_target):
    # Make prediction using available data (including predicted data)
    prediction = model.predict(data_for_next_prediction.reshape(1,-1, 1))[0,0] # need to reshape for to get it into the right format
    
    # Use the last 10 data points for the next prediction
    data_for_next_prediction = np.roll(data_for_next_prediction, -1)
    data_for_next_prediction[-1] = prediction
    
    # Add prediction to set of predictions
    validation_predictions.append(prediction)

# %%
# plot predicted vs actual test data
plt.figure(figsize=(15,5))
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend();

# %% [markdown]
# It looks like it does better. The frequency looks right in the beginning, but doesn't look so good after that (it doesn't know in the second half that the frequency slows down)

# %% [markdown]
# ### Try an LSTM

# %%
# Define the layers of the model
i = Input(shape=(T, D))
x = LSTM(10)(i) # Defailt activation is activation='tanh'
x = Dense(1)(x)

# Build the model
model = Model(i, x)

# Define how the model should be trained
model.compile(optimizer=Adam(lr=0.002),
              loss='mse')

# Train the mdoel
result = model.fit(x=X_train, y=y_train, # train on the first half of the dataset (don't use train_test_split)
                   epochs=25,
                   validation_data=(X_test, y_test)) # test on the second half of the dataset
# Out:
# Train on 4900 samples, validate on 4900 samples
# Epoch 1/25
# 4900/4900 [==============================] - 4s 821us/sample - loss: 0.4998 - val_loss: 0.4754
# Epoch 2/25
# 4900/4900 [==============================] - 2s 364us/sample - loss: 0.3210 - val_loss: 0.1226
# Epoch 3/25
# 4900/4900 [==============================] - 2s 362us/sample - loss: 0.0432 - val_loss: 0.0228
# Epoch 4/25
# 4900/4900 [==============================] - 2s 362us/sample - loss: 0.0134 - val_loss: 0.0174
# Epoch 5/25
# 4900/4900 [==============================] - 2s 358us/sample - loss: 0.0088 - val_loss: 0.0129
# Epoch 6/25
# 4900/4900 [==============================] - 2s 358us/sample - loss: 0.0068 - val_loss: 0.0113
# Epoch 7/25
# 4900/4900 [==============================] - 2s 356us/sample - loss: 0.0055 - val_loss: 0.0071
# Epoch 8/25
# 4900/4900 [==============================] - 2s 361us/sample - loss: 0.0048 - val_loss: 0.0057
# Epoch 9/25
# 4900/4900 [==============================] - 2s 362us/sample - loss: 0.0041 - val_loss: 0.0054
# Epoch 10/25
# 4900/4900 [==============================] - 2s 355us/sample - loss: 0.0036 - val_loss: 0.0037
# Epoch 11/25
# 4900/4900 [==============================] - 2s 356us/sample - loss: 0.0031 - val_loss: 0.0031
# Epoch 12/25
# 4900/4900 [==============================] - 2s 355us/sample - loss: 0.0028 - val_loss: 0.0029
# Epoch 13/25
# 4900/4900 [==============================] - 2s 354us/sample - loss: 0.0025 - val_loss: 0.0024
# Epoch 14/25
# 4900/4900 [==============================] - 2s 357us/sample - loss: 0.0023 - val_loss: 0.0027
# Epoch 15/25
# 4900/4900 [==============================] - 2s 354us/sample - loss: 0.0021 - val_loss: 0.0021
# Epoch 16/25
# 4900/4900 [==============================] - 2s 354us/sample - loss: 0.0019 - val_loss: 0.0019
# Epoch 17/25
# 4900/4900 [==============================] - 2s 355us/sample - loss: 0.0018 - val_loss: 0.0018
# Epoch 18/25
# 4900/4900 [==============================] - 2s 363us/sample - loss: 0.0016 - val_loss: 0.0017
# Epoch 19/25
# 4900/4900 [==============================] - 2s 355us/sample - loss: 0.0015 - val_loss: 0.0015
# Epoch 20/25
# 4900/4900 [==============================] - 2s 357us/sample - loss: 0.0015 - val_loss: 0.0016
# Epoch 21/25
# 4900/4900 [==============================] - 2s 358us/sample - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/25
# 4900/4900 [==============================] - 2s 354us/sample - loss: 0.0013 - val_loss: 0.0014
# Epoch 23/25
# 4900/4900 [==============================] - 2s 355us/sample - loss: 0.0013 - val_loss: 0.0015
# Epoch 24/25
# 4900/4900 [==============================] - 2s 356us/sample - loss: 0.0011 - val_loss: 0.0012
# Epoch 25/25
# 4900/4900 [==============================] - 2s 356us/sample - loss: 0.0011 - val_loss: 0.0011

# %%
# Plot the cost function at each itteration
# Note: model.fit() returns an object that contains the history of the training process
plt.plot(result.history['loss'], label='train_mse');
plt.plot(result.history['val_loss'], label='val_mse');
plt.legend();

# %% [markdown]
# Try to make a forecast

# %%
# create the lists
validation_target = y_test[-T:]
data_for_next_prediction = X_test[-T]
validation_predictions = []

# start index at 0
i = 0

# make predictions
while len(validation_predictions) < len(validation_target):
    # Make prediction using available data (including predicted data)
    prediction = model.predict(data_for_next_prediction.reshape(1,-1, 1))[0,0] # need to reshape for to get it into the right format
    
    # Use the last 10 data points for the next prediction
    data_for_next_prediction = np.roll(data_for_next_prediction, -1)
    data_for_next_prediction[-1] = prediction
    
    # Add prediction to set of predictions
    validation_predictions.append(prediction)

# %%
# plot predicted vs actual test data
plt.figure(figsize=(15,5))
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend();
